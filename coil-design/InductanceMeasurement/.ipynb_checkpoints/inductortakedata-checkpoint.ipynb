# %%
# %matplotlib inline
from pylab import *
import serial

# %%
SERIAL_PORT = "com15"#PC
ser = serial.Serial( SERIAL_PORT, timeout=10.0 )
ser.setBaudrate(115200)

# %%
ser.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-37419b272216> in <module>()
# ----> 1 ser.close()
#
# NameError: name 'ser' is not defined

# %%
ser.open()
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# <ipython-input-58-9b8068ea6182> in <module>()
# ----> 1 ser.open()
#
# C:\Users\Lafe\Anaconda\lib\site-packages\serial\serialwin32.pyc in open(self)
#      64         if self.hComPort == win32.INVALID_HANDLE_VALUE:
#      65             self.hComPort = None    # 'cause __del__ is called anyway
# ---> 66             raise SerialException("could not open port %r: %r" % (self.portstr, ctypes.WinError()))
#      67
#      68         try:
#
# SerialException: could not open port 'com15': WindowsError(2, 'The system cannot find the file specified.')

# %%
def stringToArray(string):
    substring = ''
    arrayFoo = []
    for index in range(len(string)):
        if string[index].isdigit() or string[index] == '-':
            substring = substring + string[index]
        if string[index] == ',' and index !=0:
            arrayFoo.append(int(substring))
            substring = '' 
    return array(arrayFoo)
    print arrayFoo

# %%
ser.flushInput()
x = ser.readline()
y = stringToArray(x)
#deltaT = int(ser.readline())
print y
#print deltaT
# Out:
# [1023  839  717  662  625  605  595  590  577  583  580  579  578  582  581
#   580  579  584  584  579  582  585  584  583  582  580  578  583  581]

# %%
ser.flushInput()
x = ser.readline()
y = stringToArray(x)
#deltaT = int(ser.readline())
print y
#print deltaT
for index in range(99):
    ser.flushInput()
    x = ser.readline()
    y = y + stringToArray(x)
#    deltaT = deltaT + int(ser.readline())
    print y
#   print deltaT
plot(y)
# Out:
# [1023  834  719  662  623  600  591  589  578  579  583  582  581  579  576
#   582  584  578  578  584  586  585  584  582  579  581  582  578  578]
# [2046 1669 1440 1325 1245 1202 1181 1173 1164 1162 1163 1161 1164 1161 1156
#  1166 1167 1160 1158 1169 1170 1167 1168 1165 1161 1162 1162 1156 1152]
# [3069 2506 2157 1989 1869 1802 1775 1761 1752 1749 1742 1743 1749 1746 1740
#  1748 1747 1746 1743 1751 1750 1746 1743 1747 1745 1747 1746 1739 1733]
# [4092 3343 2875 2650 2497 2402 2363 2347 2339 2336 2327 2326 2333 2332 2325
#  2333 2330 2326 2328 2332 2334 2333 2323 2326 2329 2333 2327 2318 2316]
# [5115 4180 3595 3315 3120 3006 2955 2936 2927 2921 2909 2910 2918 2916 2909
#  2917 2915 2905 2907 2916 2920 2918 2907 2908 2915 2918 2911 2902 2897]
# [6138 5017 4311 3974 3747 3606 3547 3526 3515 3506 3492 3492 3504 3500 3492
#  3498 3495 3484 3490 3499 3505 3503 3491 3490 3496 3498 3495 3485 3478]
# [7161 5853 5032 4638 4378 4209 4138 4116 4102 4091 4074 4073 4088 4083 4073
# ...

# %%
deltaT/100.0/1000.0
# Out:
# 9.02432

# %%
deltaT = 9.024

# %%
R = 2.3 + 3.1
R
# Out:
# 5.4

# %%
y = y/100.0

# %%
y = y - min(y)*ones(len(y))

# %%
y = y/max(y)

# %%
plot(log(y),'o')
grid()
axis([0,10,-7,0])
# Out:
# C:\Users\Lafe\Anaconda\lib\site-packages\ipykernel\__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':
# [0, 10, -7, 0]

# %%
t  = linspace(0,9.024,len(y))

# %%
plot(t,log(y),'o',t,-t/0.54, linewidth = 2)
grid()
axis([0,8,-10,0])


xlabel('time [ms]',fontsize  = 16)
ylabel('normalized log current',fontsize  = 16)
title('L/R time = 0.54 ms',fontsize  = 16)


#xkcd(scale = .5)

# %%
plot(t,log(y),'o',t,-t/0.54, linewidth = 2)
grid()
axis([0,8,-10,0])
#xkcd(scale = 5)

xlabel('time [ms]',fontsize  = 56)
ylabel('normalized log current',fontsize  = 56)
title('L/R time = 0.54 ms',fontsize  = 56)
# Out:
# C:\Users\Lafe\Anaconda\lib\site-packages\ipykernel\__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-c230e8c9b6ea> in <module>()
# ----> 1 'butt'.caps
#
# AttributeError: 'str' object has no attribute 'caps'

# %%
t2 = linspace(t[0],t[len(t)-1],len(t)*10)

semilogy(t,y,'o',t2,exp(-t2/0.54), linewidth = 2)
grid()
axis([0,4.0,0,1.1])
xlabel('time [ms]',fontsize  = 16)
ylabel('normalized current',fontsize  = 16)
title('L/R time = 0.54 ms',fontsize  = 16)

# %%
#t2 = linspace(t[0],t[len(t)-1],len(t)*10)

plot(t,20*log10(abs(y+.0000001 - exp(-t/0.54))),'o' ,linewidth = 2)
grid()
axis([0,4.0,-120,0])
xlabel('time [ms]',fontsize  = 16)
ylabel('log residuals [dB]',fontsize  = 16)
title('L/R time = 0.54 ms',fontsize  = 16)

# %%
20*log10(abs(y+.0000001 - exp(-t/0.54)))
# Out:
# array([-139.99999999,  -32.89513311,  -44.68005844,  -37.43305862,
#         -42.23984391,  -59.27635743,  -47.70476441,  -56.28860117,
#         -94.31220467,  -65.84178188,  -57.77622833,  -79.4079822 ,
#         -54.87807232,  -57.32775496,  -57.29726327,  -64.85284621,
#         -53.64742201,  -55.26233087,  -66.44453832,  -60.98215903,
#         -51.56689355,  -56.53896071,  -64.97961848,  -54.22389145,
#         -50.83486985,  -51.62103332,  -52.65299031,  -54.95688793,
#         -51.62012004])

# %%
L = R*0.54 #in milihenries
L
# Out:
# 2.9160000000000004

# %%
t = arange(len(y))*0.1
plot(t,y,'o',t,448.0-750.0*t)
axis([0,0.65,0,500])
xlabel('time [ms]')
ylabel('log(i0-i(t))')
title('L/R time measurement')
grid()

# %%
ser.flushInput()
x = ''
for index in range(10000):
    x = x+ ser.read()

y =stringToArray(x)
plot(y,'o')

# %%
t = array(range(len(y[1700:])))
z = y[1700:]
z = array(z)/1023.

# %%
plot(t,log(z),'o',t,-t/700.)

# %%
plot(log(y[1700:]),'o')

# %%
plot(t,log(z),'o',t,6.93 - t/70.)
axis([0,300,2,7])

# %%
t = array(range(len(y[240:1000])))

# %%
z = y[240:1000]

# %%
log(1023)

# %%
ser.close()

# %% [raw]
# ser.open()

# %%
ser.readline()

# %%
semilogy(t,y,linewidth = 2)
grid()

# %%
y = load('100avgs.npy')

# %%
y
# Out:
# array([  1.00000000e+00,   5.73215700e-01,   3.08946952e-01,
#          1.80318968e-01,   9.96041172e-02,   4.94966633e-02,
#          2.37303472e-02,   1.37993440e-02,   8.46058138e-03,
#          5.15778758e-03,   1.26682502e-03,   1.51566565e-03,
#          2.57889379e-03,   1.78712815e-03,   1.60000000e-03,
#          7.01278136e-04,   2.14907816e-03,   1.76450628e-03,
#          4.97681258e-04,   9.04875014e-04,   2.64675942e-03,
#          1.49304377e-03,   5.65546884e-04,   1.94548128e-03,
#          2.87297817e-03,   2.62413754e-03,   2.33005316e-03,
#          1.78712815e-03,   2.62413754e-03])

# %%
y[14] = 1.6e-3
